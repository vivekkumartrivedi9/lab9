# %%
#importing the required packages
import pandas as pd

# %%
#Please copy the 'cleveland_heart_attr.csv' and 'cleveland_heart_attr_description.txt' files to the current folder in colab
#read the csv file into a dataframe
df = pd.read_csv('cleveland_heart_attr.csv')

# %%
#check the data frame by printing its first few rows 
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 0                                     2.3                   3.0
# 1                                     1.5                   2.0
# ...

# %%
#check the data frame by printing its last  few rows 
df.tail()
# Out:
#       age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 298  45.0  1.0              1.0    110.0              264.0              0.0
# 299  68.0  1.0              4.0    144.0              193.0              1.0
# 300  57.0  1.0              4.0    130.0              131.0              0.0
# 301  57.0  0.0              2.0    130.0              236.0              0.0
# 302  38.0  1.0              3.0    138.0              175.0              0.0
#
#      rest_ecg  max_heartrate  exercise_angina  \
# 298       0.0          132.0              0.0
# 299       0.0          141.0              0.0
# 300       0.0          115.0              1.0
# 301       2.0          174.0              0.0
# 302       0.0          173.0              0.0
#
#      ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 298                                     1.2                   2.0
# 299                                     3.4                   2.0
# ...

# %%
df
# Out:
#       age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0    63.0  1.0              1.0    145.0              233.0              1.0
# 1    67.0  1.0              4.0    160.0              286.0              0.0
# 2    67.0  1.0              4.0    120.0              229.0              0.0
# 3    37.0  1.0              3.0    130.0              250.0              0.0
# 4    41.0  0.0              2.0    130.0              204.0              0.0
# ..    ...  ...              ...      ...                ...              ...
# 298  45.0  1.0              1.0    110.0              264.0              0.0
# 299  68.0  1.0              4.0    144.0              193.0              1.0
# 300  57.0  1.0              4.0    130.0              131.0              0.0
# 301  57.0  0.0              2.0    130.0              236.0              0.0
# 302  38.0  1.0              3.0    138.0              175.0              0.0
#
# ...

# %%
#[R]
#how many rows and columns does df have?
#Fill the appropriate code here
print('no of row =',df.shape[0],'\n','no of columns =',df.shape[1])
# Out:
# no of row = 303
#  no of columns = 14

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.1}$
#
# no of row = 303
#
#  no of columns = 14

# %%
#Printing the columns in df
print(df.columns)
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'rest_bp', 'serum_cholesterol',
#        'fastblood_sugar', 'rest_ecg', 'max_heartrate', 'exercise_angina',
#        'ST_depression_exercise_relativeto_rest', 'slope_peak_STsegment',
#        'num_major_vessels_fluroscopy', 'thal', 'heart_disease_status'],
#       dtype='object')

# %%
#Let us try to check the description of the data 
data_description = open('cleveland_heart_attr_description.txt','r').read()
print (data_description)
# Out:
# Publication Request:
#    >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#    This file describes the contents of the heart-disease directory.
#
#    This directory contains 1 database concerning heart disease diagnosis.
#    All attributes are numeric-valued.  The data was collected from the
#     following location:
#
#      1. Cleveland Clinic Foundation (cleveland.data)
#
# While the database contains 76 attributes, only  14 attributes were actually used in past experiments.
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# 1. Title: Heart Disease Databases
#
# 2. Source Information:
#    (a) Creators:
#        -- 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
#    (b) Donor: David W. Aha (aha@ics.uci.edu) (714) 856-8779
#    (c) Date: July, 1988
#
#
# 3. Relevant Information:
#      This database contains 76 attributes, but all published experiments
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    float64
#  2   chest_pain_type                         303 non-null    float64
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    float64
#  6   rest_ecg                                303 non-null    float64
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    float64
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %%
for i in range(df.shape[0]):
  if type(df.loc[i,'num_major_vessels_fluroscopy'])!=str:
    print('other than string data found')

# %%
#If an explicit description about data is missing, we can try to understand the data using basic statistical information
df.describe()
# Out:
#               age         sex  chest_pain_type     rest_bp  serum_cholesterol  \
# count  303.000000  303.000000       303.000000  303.000000         303.000000
# mean    54.438944    0.679868         3.158416  131.689769         246.693069
# std      9.038662    0.467299         0.960126   17.599748          51.776918
# min     29.000000    0.000000         1.000000   94.000000         126.000000
# 25%     48.000000    0.000000         3.000000  120.000000         211.000000
# 50%     56.000000    1.000000         3.000000  130.000000         241.000000
# 75%     61.000000    1.000000         4.000000  140.000000         275.000000
# max     77.000000    1.000000         4.000000  200.000000         564.000000
#
#        fastblood_sugar    rest_ecg  max_heartrate  exercise_angina  \
# count       303.000000  303.000000     303.000000       303.000000
# mean          0.148515    0.990099     149.607261         0.326733
# ...

# %%
#we can use the following for attributes with object dtype 
df.describe(include=object)
#Try to see if the results make sense.
# Out:
#        num_major_vessels_fluroscopy thal
# count                           303  303
# unique                            5    4
# top                             0.0  3.0
# freq                            176  166

# %%
#[R]Why are the num_major_vessels_fluroscopy and thal columns considered object types? Write the reason.
for i in range(df.shape[0]):
  if type(df.loc[i,'num_major_vessels_fluroscopy'])!=str:
    print('other than string data found')

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.2}$
#
# here every element of the num_major_vessels_fluroscopy column is of type string so pandas  takes datatype as 'object'
# in our data it is of mixed type so dtype is 'object' is taken by pandas since dtype is more general data type it is assigned to that column because of it contains two type of data float and string (in 166 192 and also in some more row data is not there and it is assigned as'?') because of that column is taken as object data type

# %%
#we change the sex attribute to categorical
df["sex"] = df["sex"].astype('category')

# %%
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 0                                     2.3                   3.0
# 1                                     1.5                   2.0
# ...

# %%
#Now we can use describe() to see statistics of sex attribute
df.describe(include='category')
# Out:
#           sex
# count   303.0
# unique    2.0
# top       1.0
# freq    206.0

# %%
#[R]
# Find another categorical attribute in df, change its dtype to 'category' 
df["chest_pain_type"] = df['chest_pain_type'].astype('category')
# Then use describe() to see statistics of that attribute
df.describe(include='category')
# Out:
#           sex  chest_pain_type
# count   303.0            303.0
# unique    2.0              4.0
# top       1.0              4.0
# freq    206.0            144.0

# %% [markdown]
# $\huge{solution  \ \ of \ \ 1.3}$
#
# in our data set 8 categorical attribute
#
# $\textbf{1.}$chest pain type
# chest pain type
#
# Value 1: typical angina
#
#  Value 2: atypical angina
#
# Value 3: non-anginal pain
#
#  Value 4: asymptomatic
#
#  $\textbf{2.}$ fast blood sugar
#  value 1:  fasting blood sugar > 120 mg/dl
#
# value 0:  fasting blood sugar < 120 mg/dl
#
# $\textbf{3.}$ resting electrocardiographic results
#
# Value 0: normal
#
# Value 1: having ST-T wave abnormality (T wave inversions and/or ST
#          elevation or depression of > 0.05 mV)
#
#  Value 2: showing probable or definite left ventricular hypertrophy
#                     by Estes' criteria
#
# $\textbf{4.}$ exercise induced angina (1 = yes; 0 = no)
#
# $\textbf{5.}$ slope: the slope of the peak exercise ST segment
#
# Value 1: upsloping
#
#  Value 2: flat
#
#  Value 3: downsloping
#
#  $\textbf{6.}$number of major vessels (0-3) colored by flourosopy
#
#  $\textbf{7.}$ thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
#  $\textbf{8.}$num: diagnosis of heart disease (angiographic disease status)
#
# Value 0: < 50% diameter narrowing
#
# Value 1: > 50% diameter narrowing

# %%
df['fastblood_sugar'] = df['fastblood_sugar'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar
# count   303.0            303.0            303.0
# unique    2.0              4.0              2.0
# top       1.0              4.0              0.0
# freq    206.0            144.0            258.0

# %%
df['rest_ecg'] = df['rest_ecg'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg
# count   303.0            303.0            303.0     303.0
# unique    2.0              4.0              2.0       3.0
# top       1.0              4.0              0.0       0.0
# freq    206.0            144.0            258.0     151.0

# %%
df['exercise_angina'] = df['exercise_angina'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg  exercise_angina
# count   303.0            303.0            303.0     303.0            303.0
# unique    2.0              4.0              2.0       3.0              2.0
# top       1.0              4.0              0.0       0.0              0.0
# freq    206.0            144.0            258.0     151.0            204.0

# %%
df['slope_peak_STsegment'] = df['slope_peak_STsegment'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg  exercise_angina  \
# count   303.0            303.0            303.0     303.0            303.0
# unique    2.0              4.0              2.0       3.0              2.0
# top       1.0              4.0              0.0       0.0              0.0
# freq    206.0            144.0            258.0     151.0            204.0
#
#         slope_peak_STsegment
# count                  303.0
# unique                   3.0
# top                      1.0
# freq                   142.0

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'rest_bp', 'serum_cholesterol',
#        'fastblood_sugar', 'rest_ecg', 'max_heartrate', 'exercise_angina',
#        'ST_depression_exercise_relativeto_rest', 'slope_peak_STsegment',
#        'num_major_vessels_fluroscopy', 'thal', 'heart_disease_status'],
#       dtype='object')

# %%
df['num_major_vessels_fluroscopy'] = df['num_major_vessels_fluroscopy'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg  exercise_angina  \
# count   303.0            303.0            303.0     303.0            303.0
# unique    2.0              4.0              2.0       3.0              2.0
# top       1.0              4.0              0.0       0.0              0.0
# freq    206.0            144.0            258.0     151.0            204.0
#
#         slope_peak_STsegment num_major_vessels_fluroscopy
# count                  303.0                          303
# unique                   3.0                            5
# top                      1.0                          0.0
# freq                   142.0                          176

# %%
df['thal'] = df['thal'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg  exercise_angina  \
# count   303.0            303.0            303.0     303.0            303.0
# unique    2.0              4.0              2.0       3.0              2.0
# top       1.0              4.0              0.0       0.0              0.0
# freq    206.0            144.0            258.0     151.0            204.0
#
#         slope_peak_STsegment num_major_vessels_fluroscopy thal
# count                  303.0                          303  303
# unique                   3.0                            5    4
# top                      1.0                          0.0  3.0
# freq                   142.0                          176  166

# %%
df['heart_disease_status'] = df['heart_disease_status'].astype('category')
df.describe(include='category')
# Out:
#           sex  chest_pain_type  fastblood_sugar  rest_ecg  exercise_angina  \
# count   303.0            303.0            303.0     303.0            303.0
# unique    2.0              4.0              2.0       3.0              2.0
# top       1.0              4.0              0.0       0.0              0.0
# freq    206.0            144.0            258.0     151.0            204.0
#
#         slope_peak_STsegment num_major_vessels_fluroscopy thal  \
# count                  303.0                          303  303
# unique                   3.0                            5    4
# top                      1.0                          0.0  3.0
# freq                   142.0                          176  166
#
#         heart_disease_status
# count                    303
# unique                     5
# top                        0
# freq                     164

# %%
#To get other information about the data, we can use info() 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    category
#  2   chest_pain_type                         303 non-null    category
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    category
#  6   rest_ecg                                303 non-null    category
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    category
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %%
#We can plot histograms using various packages
#For now we shall import seaborn package
import seaborn as sns

# %%
#seaborn has its own histogram plotting utility
sns.histplot(df.age)

# %%
#To avoid the appearance of <matplotlib.axes._subplots.AxesSubplot at 0x7fe18fb1c8d0> 
# we shall end the plot command with a semicolon (;)
sns.histplot(df.age);

# %%
#We can change some options in histplot and try replotting
sns.histplot(df.age,binrange=(20,60));

# %%
#The age distribution can be plotted as a graph based on the underlying histogram 
sns.histplot(df.age,kde=True);

# %%
#Replotting the distribution for a more fine-grained bin size
sns.histplot(df.age,bins=20,kde=True);
#Find the bin size in this histplot

# %%
#Replotting the distribution for 50 bins
sns.histplot(df.age,bins=50,kde=True);
#Find the bin size in this histplot

# %%
#[R] What is the KDE option useful for in histplot()? Explain the details. 
#[R] Plot seaborn based histogram with kde=True for serum_cholesterol attribute. Use bin sizes from {default, 20, 50, 100, 200, 500}. Report the observations.

# %% [markdown]
# $\huge{Solution  \ \ of  \ \ 1.4}$
#
# A kernel density estimate (KDE) is a method for visualizing the distribution of observations in a dataset, analogous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions
#
# In a KDE, each data point contributes a small area around its true value. The shape of this area is called the kernel function. Kernels can take different shapes from smooth bell curves to sharp triangular peaks. In addition, kernels can have different width, or bandwidth, affecting the influence of each individual data point
#
# Relative to a histogram, KDE can produce a plot that is less cluttered and more interpretable, especially when drawing multiple distributions. But it has the potential to introduce distortions if the underlying distribution is bounded or not smooth. Like a histogram, the quality of the representation also depends on the selection of good smoothing parameters.

# %%
sns.histplot(df.serum_cholesterol,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=20,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=50,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=100,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=200,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=500,kde=True);

# %%
(max(df['serum_cholesterol'])-min(df['serum_cholesterol']))/500
# Out:
# 0.876

# %% [markdown]
# $\huge{Solution \ \  of \ \  1.5}$
#
# If we increase no of bins it gives more accurate information about data but in distribution point of view it is not correct we can't able to find good approximated distribution so standard bin size is good in that sense if we take no of bins large each bins represent one or two data point that is not more useful we can also see from kde graph as bins size increases the kde graph is more varriate that does not give good approximation of data but it give information about all data point
# so default bin size is good in some sense
#
#  as we increase no of bins, size of bins decrease in above graph we can see that if number of bins =20 then size of bins is  21.9 in that size more data covered compare to number of bins =50 where bin size is 8.76
#  number of bins =100 bin size is 4.38 number of bins=200 bin size  is 2.19 when number of bins is 500 bin size is 0.876  also if we decrease size of bins then each bins contains less no of data point as we can see in figure as number of bins increases size of y axis decreases as no of data point decreases in each bins

# %%
import numpy as np
#Let us use bar plots now to understand about the data description
#To do this let us first introduce new column to the data frame indicating the gender of patient
df['gender'] = np.where(df['sex']==1.0,'male','female')

# %%
df.head()
#check the last column
# Out:
#     age  sex chest_pain_type  rest_bp  serum_cholesterol fastblood_sugar  \
# 0  63.0  1.0             1.0    145.0              233.0             1.0
# 1  67.0  1.0             4.0    160.0              286.0             0.0
# 2  67.0  1.0             4.0    120.0              229.0             0.0
# 3  37.0  1.0             3.0    130.0              250.0             0.0
# 4  41.0  0.0             2.0    130.0              204.0             0.0
#
#   rest_ecg  max_heartrate exercise_angina  \
# 0      2.0          150.0             0.0
# 1      2.0          108.0             1.0
# 2      2.0          129.0             1.0
# 3      0.0          187.0             0.0
# 4      2.0          172.0             0.0
#
#    ST_depression_exercise_relativeto_rest slope_peak_STsegment  \
# 0                                     2.3                  3.0
# 1                                     1.5                  2.0
# 2                                     2.6                  2.0
# ...

# %%
#We will plot bar plots using seaborn
sns.catplot(x="gender",data=df,kind='count');

# %%
sns.catplot(x="chest_pain_type",data=df,kind='count');
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())

# %%
#Let us plot the bar plot for gender vs serum_cholesterol 
sns.barplot(x="gender",y="serum_cholesterol",data=df);
#What does the plot describe? What are the vertical black bars in each bar?

# %%
#[R] Replot by changing the order in the bar plots from male, female to female, male

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.6}$

# %%
sns.barplot(x="gender",y="serum_cholesterol",data=df,order=['female','male']);

# %%
#Let us try the barplot with a different option
sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.median);
#[R] Explain the difference between the plot obtained below using the median estimator and the plot obtained above.

# %%
print('median female',np.median(df['serum_cholesterol'][df['gender']=='female']))
print('median male',np.median(df['serum_cholesterol'][df['gender']=='male']))
print('mean female',np.mean(df['serum_cholesterol'][df['gender']=='female']))
print('mean male',np.mean(df['serum_cholesterol'][df['gender']=='male']))
# Out:
# median female 254.0
# median male 235.0
# mean female 261.7525773195876
# mean male 239.60194174757282

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(ncols=2)
sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.median,ax=axs[0])
sns.barplot(x="gender",y="serum_cholesterol",data=df,ax=axs[1])

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.7}$
#
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars
#
# here if we choose two different estimator mean and  median for this data differene between mean and median is small because of that figure looks like same but not always it happen
#
# median female 254.0
#
# median male 235.0
#
# mean female 261.7525773195876
#
# mean male 239.60194174757282
#
# here clearly we can see that difference is very small only 6 units so graph looks like similar
#
# in code estimator used for  estimate of central tendency by default it takes mean in second graph we assign it median

# %%
#We can create bar plots with even more fine-grained grouping
#Let us group according to chest_pain_type
sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df);
#[R] Explain the observations from the plot.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.8}$
#
# in bar plot it describe  mean of serum cholesterol of each chest pain type for male and female clearly from graph mean of serum cholestoral in mg/dl in female is  more compare to male for each chest pain type
#
#
# male type1 239.74285714285713
#
# male type2 240.55357142857142
#
# male type3 242.71784232365144
#
# male type4 244.29674796747966
#
# female type 1 257.37931034482756
#
# female type 2 256.61240310077517
#
# female type 3 251.5810810810811
#
# female type 4 252.36318407960198
#
# also from graph error bar of each chest pain type in female is larger then male
#
# in male error bar is less i.e size of confidence interval is less (in our graph by default confidence coefficient is taken as 95%)  that shows that value are concentrated. signalling that the plotted average value is more likely
# in female error bar size is large compare to male i.e confidence interval is large that indicate that the values are more spread out and less reliable compare to male

# %%
print('male type1',np.mean(df['serum_cholesterol'][(df['gender']=='male') | (df['chest_pain_type']==1.0)]))
print('male type2',np.mean(df['serum_cholesterol'][(df['gender']=='male') | (df['chest_pain_type']==2.0)]))
print('male type3',np.mean(df['serum_cholesterol'][(df['gender']=='male') | (df['chest_pain_type']==3.0)]))
print('male type4',np.mean(df['serum_cholesterol'][(df['gender']=='male') | (df['chest_pain_type']==4.0)]))
print('female type 1',np.mean(df['serum_cholesterol'][(df['gender']=='female') | (df['chest_pain_type']==1.0)]))
print('female type 2',np.mean(df['serum_cholesterol'][(df['gender']=='female') | (df['chest_pain_type']==2.0)]))
print('female type 3',np.mean(df['serum_cholesterol'][(df['gender']=='female') | (df['chest_pain_type']==3.0)]))
print('female type 4',np.mean(df['serum_cholesterol'][(df['gender']=='female') | (df['chest_pain_type']==4.0)]))
# Out:
# male type1 239.74285714285713
# male type2 240.55357142857142
# male type3 242.71784232365144
# male type4 244.29674796747966
# female type 1 257.37931034482756
# female type 2 256.61240310077517
# female type 3 251.5810810810811
# female type 4 252.36318407960198

# %%
#We can adjust the positioning of the legend. 
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
ax.legend(loc='center left', title="chest_pain_type", bbox_to_anchor=(1, 0.5));

# %%
#[R] Note that the chest_pain_type is numerical and hence is of less value in the plot above. 
# To make the plot more meaningful, insert a new column to the dataframe which contains the description according to the corresponding chest_pain_type code. 
# Name this column as chest_pain_type_description. 
# To fill the values in this chest_pain_type_description column, take the description for chest_pain_type from description file.  
# Construct the above grouped bar plot where the grouping is now with respect to the textual description of the chest_pain_type. 
# Add an appropriate legend and display the legend in a position where the bar graphs are clearly visible.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.9}$

# %%
df['chest_pain_type_description']=df['chest_pain_type']
df['chest_pain_type_description']=df['chest_pain_type_description'].replace([1.0,2.0,3.0,4.0],['typical angina chest pain','atypical angina chest pain','non-anginal pain chest pain','asymptomatic chest pain'])

# %%
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type_description",data=df)
ax.legend(loc='center left', title="chest_pain_type", bbox_to_anchor=(1, 0.5));

# %%
#To capture whether two attributes are correlated, one way is to use scatter plot
#Let us try to see if age is related to serum_cholesterol

sns.scatterplot(x="age",y="serum_cholesterol",data=df);
#[R] Explain your observations from the scatter plot.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.10}$
#
# in this graph it represent how data is distributed according to age  also graph shows density of data here we can see that more data lies in interval (200,300) also we able to find outlier
#
#  in the graph clearly seen one data point between 60 and 70 age group is more differ from other data point that is known as outlier also we can see that through graph more data point is lies between 35-70 age group
#
# but graph point of view it shows they are    correlated   i.e seen a line that more fit to the data point since we plot scatter plot to find relation between two data set we can clearly observe that it fit's in that order

# %%
sns.regplot(x="age",y="serum_cholesterol",data=df);

# %%
#Let us plot the relation between chest_pain_type and serum_cholesterol

sns.scatterplot(x="chest_pain_type",y="serum_cholesterol",data=df);

# %%
#We can also use lineplot to plot the relationship between variables
sns.lineplot(x="age",y="serum_cholesterol",data=df,);

# %%
#[R] What do the light-colored bands and the dark central line indicate in the above line plot?

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.11}$
#
# here, light colored band showing the confidence interval, because the dataset contains multiple y(serum cholesterol) values for each x(age) value. By default, sns.lineplot() will estimate the mean by aggregating over multiple y values at each x value.
#
# After aggregation, the mean of y values at each x value will be plotted as a dark central line.light colored band represents the confidence interval of the estimate.
#
# we can see from graph age and serum cholesterol is fluctuate as age increases

# %%
#We can use blox plots which would provide details about summary statistics 
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",data=df);

# %%
#[R] What do the upper and lower boundaries of the box indicate? What does the line inside the box indicate? What are the points marked beyond the error bars?  Explain.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.12}$
#
# the box plot show quartile of data set upper boundary represent upper quartile i.e 75 th percentile
# and lower bound show lower quartile i.e 25th percentile
#
# line inside the box represent median and the point marked beyond the error bar represent outlier

# %%
#We can also group the above box plots according to gender
#recall "hue" in barplot
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",hue="gender",data=df);

# %%
#[R] Discuss the observations made from the previous box plot.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.13}$
#
# clearly from graph for chest pain type 1.0 male data point has large varriation between data compare to female and also outlier in female data type and 25 th percentile of male data point is less than female
# 75th percentile of male data point is larger than female data point
#
# for chest pain type 2.0 female data point has more varriation compare to male data point  and no outlier there. 25th percentile of male data point is larger than female data point 75th percentile of female data point is larger than male data point
#
# for chest pain type 3.0 female data type has more varriation compare to male data point. for male and female both data type there is outlier  25 th percentile of both data male and female data point are equal
# 75 th percentile of female data point is larger then male data point
#
# for chest pain type 4.0 both male and female have approx same variation of data point. no outlier for both type of data point  25th percentile of male data point is less than female data point 75 th percentile of female data type is larger than male data type

# %%
#[R] Use violinplot to plot the relationship between chest_pain_type and serum_cholesterol and discuss the observations. 
#[R] Can you group the violinplots based on gender information? If so, prepare the corresponding plots and discuss the observations.

# %%
sns.violinplot(x='chest_pain_type',y='serum_cholesterol',data=df)

# %%
sns.violinplot(x='chest_pain_type',y='serum_cholesterol',data=df,hue='gender')

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.14}$
#
# Here violin plot depicts distributions of numeric data  using density curves width of each curve represent approximate frequency of data point (kernel density estimation of the underlying distribution) i.e In a KDE, each data point contributes a small area around its true value. The shape of this area is called the kernel function in our graph it is represented by width curve in that range. white point in violine represent median of data point thick black line in the middle of each density curve  represent quartile of data point i.e 25th percentile and 75th percentile of data point.thinner line in curve can be seen in graph of female of chest paint type 3.0 that represent outlier of data point
#
# we can see that median is approx similar for each pain type and width and shape of graph varry according to chest type

# %%
sns.jointplot(x="age", y="max_heartrate", data=df, kind="reg");

# %%
np.mean(df['age'])
# Out:
# 54.43894389438944

# %%
#[R] Describe the observations obtained from the above jointplot. 
#[R] Prepare a joint plot between age and serum_cholesterol and discuss the observations.

# %%
sns.jointplot(x="age", y="serum_cholesterol", data=df, kind="reg");

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.15}$
#
# in graph it comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(max_heartrate) varies with the independent variable(age). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(age). The third plot is placed on the right margin of the bivariate graph with the orientation set to vertical and it shows the distribution of the dependent variable(max_heartrate) in the middle a line that represent best fitted line to our data set some times it is easier to correlate between two data set using jointplot because it represent regression plot of both data and also univariate plot of both data set that is easier to analyze and finding relation between both data set how it related
#
# in the joinplot of max heartrate and age dataset is negative correlated
# but in serum cholesterol data is positive correlated we can see it from best fitted line(regression line) also we can see from graph serum cholesterol has more frequent between 100-300
#
# also from graph the dataset have positive correlation between them

# %%
sns.pairplot(df, x_vars=["max_heartrate", "rest_bp"], y_vars=["age"],
             hue="gender", height=5, aspect=.8, kind="reg");

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.16}$
#
# in the pairplot of max heartrate and "rest bp"
#
# for max heartrate  dataset it is  negative correlated for both male and female
# but in "rest bp" data is positive correlated for both male and female we can see it from best fitted line(regression line)
#
# from graph it is clear as age increase max heart rate (for large data point) is decreases (from regression line) and also as age increase "rest bp" is also increases but not more since it is low correlated with age

# %%
#[R] Explain the observations obtained from the above pairplot.
#[R] Prepare a pairplot with ST_depression_exercise_relativeto_rest and serum_cholesterol along x axis and age along y axis. Explain the observations obtained from this pairplot.

# %%
sns.pairplot(df, x_vars=[ "rest_bp","serum_cholesterol"], y_vars=["age"],
             hue="gender", height=5, aspect=.8, kind="reg");

# %% [markdown]
# in the pair plot of rest_bp and serum_cholesterol both data set is low positive correlated with each other
#
# from graph we can see that rest bp and serum cholesterol increases as age increases for both male and female
#
# basically pair plot is used for combining two plot here kind is used for defining which type of graph we have to used for dataset here we used regression plot for both graph(kind="reg")

# %%
sns.pairplot(df, x_vars=[ "ST_depression_exercise_relativeto_rest","serum_cholesterol"], y_vars=["age"],
             hue="gender", height=5, aspect=.8, kind="reg");

# %% [markdown]
# $\huge{Solution \ \ of  \ \ 1.17}$
#
# here from graph it is clear that ST_depression_exercise_relativeto_rest is not correlated to age since we can not  able to get single fitted line since more data lies at 0 ST_depression_exercise_relativeto_rest and we can say by calculation that it is weak positive correlation
#
#   but serum cholesterol is low  positive correlated to age

# %%
sns.pairplot(df, 
             x_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             y_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             hue="gender", height=2.5);

# %%
#[R] Explain the observations from the previous pairplot.
#[R] Change the previous pairplot so that the off-diagonal plots are regression plots. Explain the observations from this new pairplot.

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.18}$
#
# in the above pair plot it represent how data is correlated with each other for 5 different data set
#
# for off diagonal pairplot takes scatter plot by default and for marginal plot along diagonal it takes layered kde since we used hue if we didn't used hue it takes histogram by default for diagonal

# %%
sns.pairplot(df, 
             x_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             y_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             hue="gender", height=2.5,kind="reg");

# %% [markdown]
# $\huge{solution \ \ of \ \ 1.18 \ \ and \ \  1.19}$
#
# in that graph it represent how data is correlated with each other
#
# by default pairplot takes scatter plot to represent two differnt data set and  for marginal plot along diagonal if hue is used it takes layered kde  if hue is not used it takes histogram plot
#
# here in our graph we changed kind of graph as regression plot now it represent regression plot on non diagonal entry and layered kernal density estimator for diagonal entry
#
# also from graph we can see that which data is positive correlated or which data is negative correlated
